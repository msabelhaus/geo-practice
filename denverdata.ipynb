# %% [markdown]
# <a href="https://colab.research.google.com/github/msabelhaus/geo-practice/blob/main/denverdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import geopandas as gpd

# %%
# Files found at https://denvergov.org/opendata/dataset/city-and-county-of-denver-statistical-neighborhoods
# Read in data from github
neighborhoods = gpd.read_file('')
# Out:
# ERROR:fiona._env:`/vsicurl/https://github.com/msabelhaus/geo-practice/tree/main/denver-project/statistical_neighborhoods/statistical_neighborhoods.shp' not recognized as a supported file format.
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# fiona/ogrext.pyx in fiona.ogrext.gdal_open_vector()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: '/vsicurl/https://github.com/msabelhaus/geo-practice/tree/main/denver-project/statistical_neighborhoods/statistical_neighborhoods.shp' not recognized as a supported file format.
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# <ipython-input-5-b38c7e0b51c5> in <cell line: 5>()
#       3 test = gpd.read_file('/vsicurl/https://github.com/Toblerity/Fiona/raw/master/tests/data/gre.shp')
#       4
# ...

# %%
neighborhoods
# Out:
#     NBHD_ID        NBHD_NAME TYPOLOGY                         NOTES  \
# 0        56       Sloan Lake     None                          None
# 1        39   Jefferson Park     None                          None
# 2        14        City Park     None                          None
# 3        42      Lowry Field     None                          None
# 4        27       Fort Logan     None                          None
# ..      ...              ...      ...                           ...
# 73       74      West Colfax     None  Removed NEST Status May 2023
# 74       33    Hampden South     None                          None
# 75       67         Valverde     NEST                          None
# 76        5      Barnum West     NEST                          None
# 77       66  University Park     None                          None
#
#                                              geometry
# 0   POLYGON ((-105.02523 39.75848, -105.02524 39.7...
# ...

# %%
neighborhoods.plot()
# Out:
# <Axes: >

# %%
pd.unique(neighborhoods['NBHD_NAME'])
# Out:
# array(['Sloan Lake', 'Jefferson Park', 'City Park', 'Lowry Field',
#        'Fort Logan', 'North Capitol Hill', 'Union Station', 'Speer',
#        'DIA', 'Cherry Creek', 'Cole', 'Athmar Park', 'Lincoln Park',
#        'Goldsmith', 'Montclair', 'East Colfax', 'Kennedy', 'Overland',
#        'Cory - Merrill', 'Windsor', 'CBD', 'Villa Park', 'Berkeley',
#        'Whittier', 'Hampden', 'Regis', 'Skyland', 'Baker', 'University',
#        'Southmoor Park', 'Indian Creek', 'Belcaro', 'Washington Park',
#        'University Hills', 'Hilltop', 'Harvey Park', 'City Park West',
#        'Northeast Park Hill', 'Wellshire', 'Marston',
#        'College View - South Platte', 'Central Park', 'Elyria Swansea',
#        'Globeville', 'Capitol Hill', 'Cheesman Park', 'Highland',
#        'Virginia Village', 'Barnum', 'Congress Park', 'Bear Valley',
#        'Harvey Park South', 'Montbello', 'West Highland', 'Auraria',
#        'Ruby Hill', 'Gateway - Green Valley Ranch', 'Westwood',
# ...

# %%
# sales = pd.read_csv('/content/real_property_sales_and_transfers.csv')
acs_1014 = gpd.read_file('/content/american_community_survey_nbrhd_2010_2014.shp')

# %%
acs_1014
# Out:
#          NBHD_NAME  TTL_POPULA  HISPANIC_O    WHITE   BLACK  NATIVE_AME  \
# 0     Chaffee Park      3966.0      2362.0   1457.0    33.0         0.0
# 1        Sunnyside     10427.0      5502.0   4071.0   303.0       223.0
# 2         Highland      8403.0      2241.0   5579.0   362.0        15.0
# 3       Globeville      3443.0      2323.0    946.0   122.0        13.0
# 4   Jefferson Park      2569.0      1338.0   1021.0   117.0        57.0
# ..             ...         ...         ...      ...     ...         ...
# 73     Five Points     14321.0      2755.0   9205.0  1920.0        52.0
# 74       Stapleton     16307.0      1920.0  11591.0  1619.0        51.0
# 75       Montbello     33282.0     20456.0   3472.0  7718.0         0.0
# 76     Lowry Field      8202.0       934.0   5946.0   806.0        14.0
# 77         Clayton      4513.0      2012.0   1112.0  1238.0        50.0
#
#     ASIAN  HAWAIIAN_P  OTHER_RACE  TWO_OR_MOR  ...  OCEANIA_FB  AMERICAS_F  \
# ...

# %%
len(pd.unique(acs_1014['NBHD_NAME']))
# Out:
# 78
